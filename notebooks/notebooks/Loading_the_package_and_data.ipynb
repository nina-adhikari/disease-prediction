# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
DRIVE = '/content/drive/MyDrive/Disease-Prediction/ddx-dataset/'

# %%
# !pip install git+https://github.com/nina-adhikari/disease_prediction
# Out:
# Collecting git+https://github.com/nina-adhikari/disease_prediction
#   Cloning https://github.com/nina-adhikari/disease_prediction to /tmp/pip-req-build-syf4g8vh
#   Running command git clone --filter=blob:none --quiet https://github.com/nina-adhikari/disease_prediction /tmp/pip-req-build-syf4g8vh
#   Resolved https://github.com/nina-adhikari/disease_prediction to commit fdf11fe4f77a4f8d7f7774901e1e9f577e57bb7e
#   Preparing metadata (setup.py) ... done

# %%
from disease_prediction.data import datasets as ds

# %%
df = ds.load_datasets(subsets=['train', 'test', 'validate'], directory=DRIVE)

# %%
df['train']
# Out:
#          AGE SEX                PATHOLOGY    INITIAL_EVIDENCE  swollen_nodes  \
# 1         21   M  HIV (initial infection)            sweating              0
# 10         8   M       Allergic sinusitis          itchy_nose              0
# 13        49   F              Anaphylaxis  lost_consciousness              0
# 18        69   M             Tuberculosis               cough              0
# 19        30   F             Tuberculosis         cough_blood              0
# ...      ...  ..                      ...                 ...            ...
# 1023490   30   M  HIV (initial infection)              nausea              0
# 1023491    7   F  HIV (initial infection)              nausea              0
# 1023492   66   F  HIV (initial infection)                pain              0
# 1023493   54   M  HIV (initial infection)            sweating              0
# 1023494   22   M  HIV (initial infection)                pain              0
#
#          std  sweating  diarrhea  pain pain_char  ... ca_blockers  \
# 1          0         0         0     0        NA  ...           0
# 10         0         0         0     1     heavy  ...           0
# 13         0         0         0     0        NA  ...           0
# 18         0         0         0     1     heavy  ...           0
# 19         0         0         0     1     sharp  ...           0
# ...      ...       ...       ...   ...       ...  ...         ...
# 1023490    0         0         0     0        NA  ...           0
# 1023491    0         0         0     0        NA  ...           0
# 1023492    0         0         0     0        NA  ...           0
# 1023493    0         0         0     0        NA  ...           0
# 1023494    0         0         0     0        NA  ...           0
#
#          vag_discharge wheezing_inhale  fatigue  menarche_12  breastfed_9  \
# 1                    0               0        0            0            0
# 10                   0               0        0            0            0
# 13                   0               0        0            0            0
# 18                   0               0        0            0            0
# 19                   0               0        0            0            0
# ...                ...             ...      ...          ...          ...
# 1023490              0               0        0            0            0
# 1023491              0               0        0            0            0
# 1023492              0               0        0            0            0
# 1023493              0               0        0            0            0
# 1023494              0               0        0            0            0
#
#          confusion  contact ebolacase bruising
# 1                0        0         0        0
# 10               0        0         0        0
# 13               0        0         0        0
# 18               0        0         0        0
# 19               0        0         0        0
# ...            ...      ...       ...      ...
# 1023490          0        0         0        0
# 1023491          0        0         0        0
# 1023492          0        0         0        0
# 1023493          0        0         0        0
# 1023494          0        0         0        0
#
# [203008 rows x 94 columns]
